# %%
import pandas as pd 
from anytree import Node, RenderTree
path = 'C:\\Users\\92007848\\Documents\\AIProj\\AiTeste\\Recomender\\resources\\capes.txt'

# %%
data = pd.read_csv(path, sep='\t', encoding='latin-1') 
data.head()
# Out:
#    idCapes  idCapesPai    codigo                        nome  nivel
# 0        1         NaN  10000003  CIÊNCIAS EXATAS E DA TERRA      1
# 1        2         1.0  10100008                  MATEMÁTICA      2
# 2        3         2.0  10101004                     ALGEBRA      3
# 3        4         3.0  10101012                   CONJUNTOS      4
# 4        5         3.0  10101020           LÓGICA MATEMÁTICA      4

# %%
root = []
for index, x in data.iterrows():
    root.append(Node(x[3],))
    
    
    
    #print(index,x[3])

# %%
print(root)
# Out:
# [Node('/CIÊNCIAS EXATAS E DA TERRA'), Node('/MATEMÁTICA'), Node('/ALGEBRA'), Node('/CONJUNTOS'), Node('/LÓGICA MATEMÁTICA'), Node('/TEORIA DOS NÚMEROS'), Node('/GRUPO DE ÁLGEBRA NÃO-COMUTATIVA'), Node('/ÁLGEBRA COMUTATIVA'), Node('/GEOMETRIA ALGÉBRICA'), Node('/ANÁLISE'), Node('/ANÁLISE COMPLEXA'), Node('/ANÁLISE FUNCIONAL'), Node('/ANÁLISE FUNCIONAL NÃO-LINEAR'), Node('/EQUAÇÕES DIFERENCIAIS ORDINÁRIAS'), Node('/EQUAÇÕES DIFERENCIAIS PARCIAIS'), Node('/EQUAÇÕES DIFERENCIAIS FUNCIONAIS'), Node('/GEOMETRIA E TOPOLOGIA'), Node('/GEOMETRIA DIFERÊNCIAL'), Node('/TOPOLOGIA ALGÉBRICA'), Node('/TOPOLOGIA DAS VARIEDADES'), Node('/SISTEMAS DINÂMICOS'), Node('/TEORIA DAS SINGULARIDADES E TEORIA DAS CATÁSTROFES'), Node('/TEORIA DAS FOLHEAÇÕES'), Node('/MATEMÁTICA APLICADA'), Node('/FÍSICA MATEMÁTICA'), Node('/ANÁLISE NUMÉRICA'), Node('/MATEMÁTICA DISCRETA E COMBINATÓRIA'), Node('/PROBABILIDADE E ESTATÍSTICA'), Node('/TEORIA GERAL E FUNDAMENTOS DA PROBABILIDADE'), Node('/TEORIA GERAL E PROCESSOS ESTOCÁSTICOS'), Node('/TEOREMAS DE LIMITE'), Node('/PROCESSOS MARKOVIANOS'), Node('/ANÁLISE ESTOCÁSTICA'), Node('/PROCESSOS ESTOCÁSTICOS ESPECIAIS'), Node('/ESTATÍSTICA'), Node('/FUNDAMENTOS DA ESTATÍSTICA'), Node('/INFERÊNCIA PARAMÉTRICA'), Node('/INFERÊNCIA NÃO-PARAMÉTRICA'), Node('/INFERÊNCIA EM PROCESSOS ESTOCÁSTICOS'), Node('/ANÁLISE MULTIVARIADA'), Node('/REGRESSÃO E CORRELAÇÃO'), Node('/PLANEJAMENTO DE EXPERIMENTOS'), Node('/ANÁLISE DE DADOS'), Node('/PROBABILIDADE E ESTATÍSTICA APLICADAS'), Node('/CIÊNCIA DA COMPUTAÇÃO'), Node('/TEORIA DA COMPUTAÇÃO'), Node('/COMPUTABILIDADE E MODELOS DE COMPUTAÇÃO'), Node('/LINGUAGEM FORMAIS E AUTÔMATOS'), Node('/ANÁLISE DE ALGORÍTMOS E COMPLEXIDADE DE COMPUTAÇÃO'), Node('/LÓGICAS E SEMÂNTICA DE PROGRAMAS'), Node('/MATEMÁTICA DA COMPUTAÇÃO'), Node('/MATEMÁTICA SIMBÓLICA'), Node('/MODELOS ANALÍTICOS E DE SIMULAÇÃO'), Node('/METODOLOGIA E TÉCNICAS DA COMPUTAÇÃO'), Node('/LINGUAGENS DE PROGRAMAÇÃO'), Node('/ENGENHARIA DE SOFTWARE'), Node('/BANCO DE DADOS'), Node('/SISTEMAS DE INFORMAÇÃO'), Node('/PROCESSAMENTO GRÁFICO (GRAPHICS)'), Node('/SISTEMA DE COMPUTAÇÃO'), Node('/HARDWARE'), Node('/ARQUITETURA DE SISTEMAS DE COMPUTAÇÃO'), Node('/SOFTWARE BÁSICO'), Node('/TELEINFORMÁTICA'), Node('/ASTRONOMIA'), Node('/ASTRONOMIA DE POSIÇÃO E MECÂNICA CELESTE'), Node('/ASTRONOMIA FUNDAMENTAL'), Node('/ASTRONOMIA DINÂMICA'), Node('/ASTROFÍSICA ESTELAR'), Node('/ASTROFÍSICA DO MEIO INTERESTELAR'), Node('/MEIO INTERESTELAR'), Node('/NEBULOSA'), Node('/ASTROFÍSICA EXTRAGALÁTICA'), Node('/GALÁXIAS'), Node('/AGLOMERADOS DE GALÁXIAS'), Node('/QUASARES'), Node('/COSMOLOGIA'), Node('/ASTROFÍSICA DO SISTEMA SOLAR'), Node('/FÍSICA SOLAR'), Node('/MOVIMENTO DA TERRA'), Node('/SISTEMA PLANETÁRIO'), Node('/INSTRUMENTAÇÃO ASTRONÔMICA'), Node('/ASTRONOMIA ÓTICA'), Node('/RADIOASTRONOMIA'), Node('/ASTRONOMIA ESPACIAL'), Node('/PROCESSAMENTO DE DADOS ASTRONÔMICOS'), Node('/FÍSICA'), Node('/FÍSICA GERAL'), Node('/MÉTODOS MATEMÁTICOS DA FÍSICA'), Node('/FÍSICA CLÁSSICA E FÍSICA QUÂNTICA; MECÂNICA E CAMPOS'), Node('/RELATIVIDADE E GRAVITAÇÃO'), Node('/FÍSICA ESTATÍSTICA E TERMODINÂMICA'), Node('/METROLOGIA, TECN. GER. DE LAB. E SIST. DE INSTRUMENTAÇÃO'), Node('/INSTRUMENTAÇÃO ESPECÍFICA DE USO GERAL EM FÍSICA'), Node('/ÁREAS CLÁSSICAS DE FENOMENOLOGIA E SUAS APLICAÇÕES'), Node('/ELETRICIDADE E MAGNETISMO; CAMPOS E PARTÍCULAS CARREGADAS'), Node('/ÓTICA'), Node('/ACÚSTICA'), Node('/TRANSFERÊNCIA DE CALOR; PROCESSOS TÉRMICOS E TERMODINÂMICOS'), Node('/MECÂNICA, ELASTICIDADE E REOLOGIA'), Node('/DINÂMICA DOS FLUIDOS'), Node('/FÍSICA DAS PARTÍCULAS ELEMENTARES E CAMPOS'), Node('/TEORIA GERAL DE PARTÍCULAS E CAMPOS'), Node('/TEOR.ESP.E MOD.DE INTERAÇÃO; SIST.DE PARTÍCULAS; R.CÓSMICOS'), Node('/REAÇÕES ESPECÍFICAS E FENOMIOLOGIA DE PARTÍCULAS'), Node('/PROPRIEDADES DE PARTÍCULAS ESPECÍFICAS E RESSONÂNCIAS'), Node('/FÍSICA NUCLEAR'), Node('/ESTRUTURA NUCLEAR'), Node('/DESINTEGRAÇÃO NUCLEAR E RADIOATIVIDADE'), Node('/REAÇÕES NUCLEARES E ESPALHAMENTO ...
